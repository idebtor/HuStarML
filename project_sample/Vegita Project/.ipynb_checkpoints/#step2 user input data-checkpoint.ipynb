# %% [markdown]
# ---------
# # 배추가격 예측 AI Project for 모인활
#
# Notes by kjune18@naver.com, Handong Global Univ.

# %% [markdown]
# ## 5. 저장된 학습 모델 불러오기

# %% [markdown]
# 학습모델을 저장하는 이유는 학습 모델을 저장하지 않고 사용자로부터 배추 가격 예측 요청이 발생할 때마다 매번 학습을 해서 결과를 돌려준다면 시간과 비용이 많이 들 것이기 때문이다.
#
# 따라서 서버에서 내부적으로 데이터를 이용해 학습된 모델을 사용해서 배추가격을 예측하는 것이 효율적이다.

# %%
import tensorflow.compat.v1 as tf
import numpy as np
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\lkjs8\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# 기본적인 placeholder 와 가중치와 bias 값 가져오기
X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])
W = tf.Variable(tf.random_normal([4, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 가설 가져오기
hypothesis = tf.matmul(X, W) + b

# %%
#저장된 모델 불러오는 모델 초기화
saver = tf.train.Saver()
model = tf.global_variables_initializer()

# %%
# 사용자로부터 4가지 입력 받을 수 있도록 작성
avg_temp = float(input('평균 온도: '))
min_temp = float(input('최저 온도: '))
max_temp = float(input('최고 온도: '))
rain_fall = float(input('강수량mm: '))
# Out:
# 평균 온도: 15.5
# 최저 온도: 10
# 최고 온도: 30
# 강수량mm: 5

# %% [markdown]
# ## 6. 학습 모델을 이용하여 값 출력하기

# %%
# tensorflow Session이용하여 결과 가격값 출력
with tf.Session() as sess:
    sess.run(model)     # model 불러오기
    
    save_path = "./saved.cpkt"  # cpkt파일 불러오기
    saver.restore(sess, save_path)
    
    data = ((avg_temp, min_temp, max_temp, rain_fall), )  # 기존의 학습된 데이터와 같은 2차원 배열 만들기
    arr = np.array(data, dtype=np.float32)
    
    # 예측 수행
    x_data = arr[0:4]  # avg_temp, min_temp, max_temp, rain_fall
    price = sess.run(hypothesis, feed_dict={X: x_data})
   
    print("예측한 배추가격은 ", price[0], "원 입니다.")
# Out:
# INFO:tensorflow:Restoring parameters from ./saved.cpkt
# 예측한 배추가격은  [5793.3857] 원 입니다.

# %% [markdown]
# ## 7. 데이터 시각화

# %%
import matplotlib.pyplot as plt
from pandas.io.parsers import read_csv

visualdata = read_csv('price data.csv')  # csv파일 읽어오기

xy = np.array(visualdata)    # 행렬 형태로 저장하기

# 4개의 변인
datas = xy[:, 1:-1]   # slicing x

plt.plot(xy[1000:,[0]], datas[1000:,[0]])
plt.xlabel('year')
plt.ylabel('avg_temp')
plt.show()

plt.plot(xy[1000:,[0]], datas[1000:,[1]])
plt.xlabel('year')
plt.ylabel('min_temp')
plt.show()

plt.plot(xy[1000:,[0]], datas[1000:,[2]])
plt.xlabel('year')
plt.ylabel('max_temp')
plt.show()

plt.plot(xy[1000:,[0]], datas[1000:,[3]])
plt.xlabel('year')
plt.ylabel('rain_fall')
plt.show()

# %% [markdown]
# ## 8. 다양한 경우로 확인하기

# %%
avg_tempx = np.arange(-30, 31, 1)
min_tempx = np.arange(-50, 11, 1)
max_tempx = np.arange(-10, 51, 1)
rain_fallx = np.arange(0, 61, 1)
# shuffle로 배열 섞기
np.random.shuffle(avg_tempx)
np.random.shuffle(min_tempx)
np.random.shuffle(max_tempx)
np.random.shuffle(rain_fallx)

# %%
for i in avg_tempx:
    if (min_tempx[i] <= max_tempx[i]
        and min_tempx[i] <= avg_tempx[i] <= max_tempx[i]):
        x_data_rand = np.stack((avg_tempx, min_tempx, max_tempx, rain_fallx), axis=1)

print(x_data_rand)
# Out:
# [[ 21 -29  29  44]
#  [-10 -10  38  18]
#  [  3 -49  36  13]
#  [-18 -47  13  59]
#  [ 20 -18  21  52]
#  [-13 -11   9  49]
#  [ -5   7  17   1]
#  [  4 -42  50  40]
#  [ -6 -34  -3  43]
#  [ 26 -21  45  16]
#  [ 30   3  10  53]
#  [-29  -1   3   8]
#  [-25 -25  19  50]
#  [  2   0   2  24]
#  [ 13 -16   1  23]
#  [-28  -5   8  14]
#  [-14   4   5  41]
#  [-23  10  22  45]
#  [  0 -33  34   0]
#  [ -9   2  42  22]
#  [  1  -4  47  54]
#  [ 22 -41   4   5]
#  [ -7 -22  28   6]
#  [ 25 -13  27  57]
#  [-15 -26  -1   7]
#  [-22   6  -2  60]
#  [ -2   1  -8  25]
#  [ 27 -39  49  58]
#  [  8 -24  20   3]
#  [ 28  -6  -9  47]
#  [ -4 -45  43  39]
#  [ -8  -3  26  27]
#  [-16 -20  -6   9]
#  [-21   8  39  10]
#  [-19 -40  40  21]
#  [ -3   9  44  32]
#  [ 16 -48  11  36]
#  [ 19 -30  12  31]
#  [ -1 -31  23  19]
#  [-17 -19  16  26]
#  [-11  -9  41   4]
#  [ 18 -12  46  46]
#  [-27   5  -5  15]
#  [ 23  -8  31  38]
#  [-30  -2  -4   2]
#  [-26 -32  33  28]
#  [ 29 -44  -7  51]
#  [  7 -35   7  56]
#  [  5  -7  14  34]
#  [  6 -46  15  20]
#  [ 17 -36  32  30]
#  [ 12 -27  35  35]
#  [ 11 -38   6  33]
#  [-24 -43  48  55]
#  [-20 -15  37  12]
#  [-12 -17   0  37]
#  [ 15 -28  30  42]
#  [ 10 -50  25  17]
#  [ 14 -37  24  29]
#  [ 24 -14 -10  11]
#  [  9 -23  18  48]]

# %%
# tensorflow Session이용하여 결과 가격값 출력
with tf.Session() as sess:
    sess.run(model)     # model 불러오기
    
    save_path_rand = "./saved.cpkt"  # cpkt파일 불러오기
    saver.restore(sess, save_path_rand)
    
    pricex = sess.run(hypothesis, feed_dict={X: x_data_rand})
# Out:
# INFO:tensorflow:Restoring parameters from ./saved.cpkt

# %%
#  print(price.astype(np.int))
for i in range(len(x_data_rand)):
    print("평균온도:", x_data_rand[i][0])
    print("최저온도:", x_data_rand[i][1])
    print("최고온도:", x_data_rand[i][2])
    print("강수량:", x_data_rand[i][3])
    print("예측한 배추가격은 ", pricex[i], "원 입니다.")
    print("---------------------")
# Out:
# 평균온도: 21
# 최저온도: -29
# 최고온도: 29
# 강수량: 44
# 예측한 배추가격은  [12475.107] 원 입니다.
# ---------------------
# 평균온도: -10
# 최저온도: -10
# 최고온도: 38
# 강수량: 18
# 예측한 배추가격은  [13333.195] 원 입니다.
# ---------------------
# 평균온도: 3
# 최저온도: -49
# 최고온도: 36
# 강수량: 13
# 예측한 배추가격은  [17518.064] 원 입니다.
# ---------------------
# 평균온도: -18
# 최저온도: -47
# 최고온도: 13
# 강수량: 59
# 예측한 배추가격은  [14375.867] 원 입니다.
# ---------------------
# 평균온도: 20
# 최저온도: -18
# 최고온도: 21
# 강수량: 52
# 예측한 배추가격은  [9069.6] 원 입니다.
# ---------------------
# 평균온도: -13
# 최저온도: -11
# 최고온도: 9
# 강수량: 49
# 예측한 배추가격은  [7161.009] 원 입니다.
# ---------------------
# 평균온도: -5
# 최저온도: 7
# 최고온도: 17
# 강수량: 1
# 예측한 배추가격은  [4202.4863] 원 입니다.
# ---------------------
# 평균온도: 4
# 최저온도: -42
# 최고온도: 50
# 강수량: 40
# 예측한 배추가격은  [21111.164] 원 입니다.
# ---------------------
# 평균온도: -6
# 최저온도: -34
# 최고온도: -3
# 강수량: 43
# 예측한 배추가격은  [6693.072] 원 입니다.
# ---------------------
# 평균온도: 26
# 최저온도: -21
# 최고온도: 45
# 강수량: 16
# 예측한 배추가격은  [14108.387] 원 입니다.
# ---------------------
# 평균온도: 30
# 최저온도: 3
# 최고온도: 10
# 강수량: 53
# 예측한 배추가격은  [2291.0305] 원 입니다.
# ---------------------
# 평균온도: -29
# 최저온도: -1
# 최고온도: 3
# 강수량: 8
# 예측한 배추가격은  [3724.2646] 원 입니다.
# ---------------------
# 평균온도: -25
# 최저온도: -25
# 최고온도: 19
# 강수량: 50
# 예측한 배추가격은  [12844.109] 원 입니다.
# ---------------------
# 평균온도: 2
# 최저온도: 0
# 최고온도: 2
# 강수량: 24
# 예측한 배추가격은  [1611.1187] 원 입니다.
# ---------------------
# 평균온도: 13
# 최저온도: -16
# 최고온도: 1
# 강수량: 23
# 예측한 배추가격은  [2900.4297] 원 입니다.
# ---------------------
# 평균온도: -28
# 최저온도: -5
# 최고온도: 8
# 강수량: 14
# 예측한 배추가격은  [5801.694] 원 입니다.
# ---------------------
# 평균온도: -14
# 최저온도: 4
# 최고온도: 5
# 강수량: 41
# 예측한 배추가격은  [3621.0308] 원 입니다.
# ---------------------
# 평균온도: -23
# 최저온도: 10
# 최고온도: 22
# 강수량: 45
# 예측한 배추가격은  [8045.0977] 원 입니다.
# ---------------------
# 평균온도: 0
# 최저온도: -33
# 최고온도: 34
# 강수량: 0
# 예측한 배추가격은  [14320.584] 원 입니다.
# ---------------------
# 평균온도: -9
# 최저온도: 2
# 최고온도: 42
# 강수량: 22
# 예측한 배추가격은  [12665.629] 원 입니다.
# ---------------------
# 평균온도: 1
# 최저온도: -4
# 최고온도: 47
# 강수량: 54
# 예측한 배추가격은  [15344.748] 원 입니다.
# ---------------------
# 평균온도: 22
# 최저온도: -41
# 최고온도: 4
# 강수량: 5
# 예측한 배추가격은  [6120.2427] 원 입니다.
# ---------------------
# 평균온도: -7
# 최저온도: -22
# 최고온도: 28
# 강수량: 6
# 예측한 배추가격은  [11815.185] 원 입니다.
# ---------------------
# 평균온도: 25
# 최저온도: -13
# 최고온도: 27
# 강수량: 57
# 예측한 배추가격은  [9726.543] 원 입니다.
# ---------------------
# 평균온도: -15
# 최저온도: -26
# 최고온도: -1
# 강수량: 7
# 예측한 배추가격은  [5348.4897] 원 입니다.
# ---------------------
# 평균온도: -22
# 최저온도: 6
# 최고온도: -2
# 강수량: 60
# 예측한 배추가격은  [2760.374] 원 입니다.
# ---------------------
# 평균온도: -2
# 최저온도: 1
# 최고온도: -8
# 강수량: 25
# 예측한 배추가격은  [-860.3087] 원 입니다.
# ---------------------
# 평균온도: 27
# 최저온도: -39
# 최고온도: 49
# 강수량: 58
# 예측한 배추가격은  [19363.242] 원 입니다.
# ---------------------
# 평균온도: 8
# 최저온도: -24
# 최고온도: 20
# 강수량: 3
# 예측한 배추가격은  [8771.968] 원 입니다.
# ---------------------
# 평균온도: 28
# 최저온도: -6
# 최고온도: -9
# 강수량: 47
# 예측한 배추가격은  [-1473.8502] 원 입니다.
# ---------------------
# 평균온도: -4
# 최저온도: -45
# 최고온도: 43
# 강수량: 39
# 예측한 배추가격은  [20258.682] 원 입니다.
# ---------------------
# 평균온도: -8
# 최저온도: -3
# 최고온도: 26
# 강수량: 27
# 예측한 배추가격은  [9282.731] 원 입니다.
# ---------------------
# 평균온도: -16
# 최저온도: -20
# 최고온도: -6
# 강수량: 9
# 예측한 배추가격은  [3267.7915] 원 입니다.
# ---------------------
# 평균온도: -21
# 최저온도: 8
# 최고온도: 39
# 강수량: 10
# 예측한 배추가격은  [11408.669] 원 입니다.
# ---------------------
# 평균온도: -19
# 최저온도: -40
# 최고온도: 40
# 강수량: 21
# 예측한 배추가격은  [19150.832] 원 입니다.
# ---------------------
# 평균온도: -3
# 최저온도: 9
# 최고온도: 44
# 강수량: 32
# 예측한 배추가격은  [12072.226] 원 입니다.
# ---------------------
# 평균온도: 16
# 최저온도: -48
# 최고온도: 11
# 강수량: 36
# 예측한 배추가격은  [10626.387] 원 입니다.
# ---------------------
# 평균온도: 19
# 최저온도: -30
# 최고온도: 12
# 강수량: 31
# 예측한 배추가격은  [7778.1997] 원 입니다.
# ---------------------
# 평균온도: -1
# 최저온도: -31
# 최고온도: 23
# 강수량: 19
# 예측한 배추가격은  [11880.721] 원 입니다.
# ---------------------
# 평균온도: -17
# 최저온도: -19
# 최고온도: 16
# 강수량: 26
# 예측한 배추가격은  [9662.237] 원 입니다.
# ---------------------
# 평균온도: -11
# 최저온도: -9
# 최고온도: 41
# 강수량: 4
# 예측한 배추가격은  [13532.594] 원 입니다.
# ---------------------
# 평균온도: 18
# 최저온도: -12
# 최고온도: 46
# 강수량: 46
# 예측한 배추가격은  [14727.572] 원 입니다.
# ---------------------
# 평균온도: -27
# 최저온도: 5
# 최고온도: -5
# 강수량: 15
# 예측한 배추가격은  [811.3968] 원 입니다.
# ---------------------
# 평균온도: 23
# 최저온도: -8
# 최고온도: 31
# 강수량: 38
# 예측한 배추가격은  [9478.107] 원 입니다.
# ---------------------
# 평균온도: -30
# 최저온도: -2
# 최고온도: -4
# 강수량: 2
# 예측한 배추가격은  [1867.6665] 원 입니다.
# ---------------------
# 평균온도: -26
# 최저온도: -32
# 최고온도: 33
# 강수량: 28
# 예측한 배추가격은  [16868.186] 원 입니다.
# ---------------------
# 평균온도: 29
# 최저온도: -44
# 최고온도: -7
# 강수량: 51
# 예측한 배추가격은  [4844.1665] 원 입니다.
# ---------------------
# 평균온도: 7
# 최저온도: -35
# 최고온도: 7
# 강수량: 56
# 예측한 배추가격은  [9019.451] 원 입니다.
# ---------------------
# 평균온도: 5
# 최저온도: -7
# 최고온도: 14
# 강수량: 34
# 예측한 배추가격은  [5998.1694] 원 입니다.
# ---------------------
# 평균온도: 6
# 최저온도: -46
# 최고온도: 15
# 강수량: 20
# 예측한 배추가격은  [11531.988] 원 입니다.
# ---------------------
# 평균온도: 17
# 최저온도: -36
# 최고온도: 32
# 강수량: 30
# 예측한 배추가격은  [14098.954] 원 입니다.
# ---------------------
# 평균온도: 12
# 최저온도: -27
# 최고온도: 35
# 강수량: 35
# 예측한 배추가격은  [14097.79] 원 입니다.
# ---------------------
# 평균온도: 11
# 최저온도: -38
# 최고온도: 6
# 강수량: 33
# 예측한 배추가격은  [8054.278] 원 입니다.
# ---------------------
# 평균온도: -24
# 최저온도: -43
# 최고온도: 48
# 강수량: 55
# 예측한 배추가격은  [23358.648] 원 입니다.
# ---------------------
# 평균온도: -20
# 최저온도: -15
# 최고온도: 37
# 강수량: 12
# 예측한 배추가격은  [14335.806] 원 입니다.
# ---------------------
# 평균온도: -12
# 최저온도: -17
# 최고온도: 0
# 강수량: 37
# 예측한 배추가격은  [5154.3193] 원 입니다.
# ---------------------
# 평균온도: 15
# 최저온도: -28
# 최고온도: 30
# 강수량: 42
# 예측한 배추가격은  [12959.486] 원 입니다.
# ---------------------
# 평균온도: 10
# 최저온도: -50
# 최고온도: 25
# 강수량: 17
# 예측한 배추가격은  [14380.054] 원 입니다.
# ---------------------
# 평균온도: 14
# 최저온도: -37
# 최고온도: 24
# 강수량: 29
# 예측한 배추가격은  [12310.701] 원 입니다.
# ---------------------
# 평균온도: 24
# 최저온도: -14
# 최고온도: -10
# 강수량: 11
# 예측한 배추가격은  [-1579.1064] 원 입니다.
# ---------------------
# 평균온도: 9
# 최저온도: -23
# 최고온도: 18
# 강수량: 48
# 예측한 배추가격은  [9689.689] 원 입니다.
# ---------------------

# %% [markdown]
# ------------------------------------------------------------------

# %%
# 사용자로부터 4가지 입력 받을 수 있도록 작성
avg_temp = float(input('평균 온도: '))
min_temp = float(input('최저 온도: '))
max_temp = float(input('최고 온도: '))
rain_fall = float(input('강수량mm: '))
# Out:
# 평균 온도: 15.5
# 최저 온도: 10
# 최고 온도: 30
# 강수량mm: 5

# %%
# tensorflow Ver2
import tensorflow as tf
import numpy as np
model = tf.keras.models.load_model('./saved.ckpt')

data = ((avg_temp, min_temp, max_temp, rain_fall), )  # 기존의 학습된 데이터와 같은 2차원 배열 만들기
arr = np.array(data, dtype=np.float32)

# 예측 수행
x_data = arr[0:4]  # avg_temp, min_temp, max_temp, rain_fall
price = model.predict(x_data)
   
print("예측한 배추가격은 ", price[0], "원 입니다.")
# Out:
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001F2D8A1B670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 예측한 배추가격은  [4921.7583] 원 입니다.

# %% [markdown]
# ## 참고자료

# %% [markdown]
# 1. 안경잡이개발자
# https://ndb796.tistory.com
